# %% [markdown]
# # Linear Regression: California Housing Price

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
x = housing.data
y = housing.target

print("Dataset shape:", x.shape)
print("Feature names:", housing.feature_names)
print("First 5 values of median income: ", x[:5, 0])
print("First 5 target values:", y[:5])
# Out:
# Dataset shape: (20640, 8)
# Feature names: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# First 5 values of median income:  [8.3252 8.3014 7.2574 5.6431 3.8462]
# First 5 target values: [4.526 3.585 3.521 3.413 3.422]

# %% [markdown]
# ## Now, we're going to implement linear regression on a single feature first: Median Income

# %%
x_simple = x[:, 0:1] 
plt.scatter(x_simple, y, alpha=0.5)
plt.xlabel(housing.feature_names[0])
plt.ylabel("House Value")
plt.title("House Value vs " + housing.feature_names[0])
plt.show()

# %%
## Forward pass: y = wx + b
# since this is linear regression on a single feature, we have only 1 weight (w), and 1 bias (b)

w = 0.5
b = 0.1

for i, income in enumerate(x[:10, 0]):
    y_pred = w * income + b
    print(f"Predicted value for {income}: {y_pred} , and target value: {y[i]}")
    print(f"Basic loss for {income}: {(y_pred - y[i])}")
# Out:
# Predicted value for 8.3252: 4.2626 , and target value: 4.526
# Basic loss for 8.3252: -0.26339999999999986
# Predicted value for 8.3014: 4.250699999999999 , and target value: 3.585
# Basic loss for 8.3014: 0.6656999999999993
# Predicted value for 7.2574: 3.7287 , and target value: 3.521
# Basic loss for 7.2574: 0.2077
# Predicted value for 5.6431: 2.92155 , and target value: 3.413
# Basic loss for 5.6431: -0.49144999999999994
# Predicted value for 3.8462: 2.0231 , and target value: 3.422
# Basic loss for 3.8462: -1.3989000000000003
# Predicted value for 4.0368: 2.1184000000000003 , and target value: 2.697
# Basic loss for 4.0368: -0.5785999999999998
# Predicted value for 3.6591: 1.92955 , and target value: 2.992
# Basic loss for 3.6591: -1.06245
# Predicted value for 3.12: 1.6600000000000001 , and target value: 2.414
# Basic loss for 3.12: -0.754
# Predicted value for 2.0804: 1.1402 , and target value: 2.267
# Basic loss for 2.0804: -1.1267999999999998
# Predicted value for 3.6912: 1.9456 , and target value: 2.611
# Basic loss for 3.6912: -0.6654000000000002

# %%
## Now, let's implement L2-Loss

for i, income in enumerate(x[:10, 0]):
    y_pred = w * income + b
    loss = (y_pred - y[i])**2
    print(f"Predicted value for {income}: {y_pred} , and target value: {y[i]}")
    print(f"L2 Loss for {income}: {loss}")
# Out:
# Predicted value for 8.3252: 4.2626 , and target value: 4.526
# L2 Loss for 8.3252: 0.06937955999999992
# Predicted value for 8.3014: 4.250699999999999 , and target value: 3.585
# L2 Loss for 8.3014: 0.44315648999999907
# Predicted value for 7.2574: 3.7287 , and target value: 3.521
# L2 Loss for 7.2574: 0.04313929
# Predicted value for 5.6431: 2.92155 , and target value: 3.413
# L2 Loss for 5.6431: 0.24152310249999995
# Predicted value for 3.8462: 2.0231 , and target value: 3.422
# L2 Loss for 3.8462: 1.9569212100000006
# Predicted value for 4.0368: 2.1184000000000003 , and target value: 2.697
# L2 Loss for 4.0368: 0.33477795999999976
# Predicted value for 3.6591: 1.92955 , and target value: 2.992
# L2 Loss for 3.6591: 1.1288000024999998
# Predicted value for 3.12: 1.6600000000000001 , and target value: 2.414
# L2 Loss for 3.12: 0.568516
# Predicted value for 2.0804: 1.1402 , and target value: 2.267
# L2 Loss for 2.0804: 1.2696782399999995
# Predicted value for 3.6912: 1.9456 , and target value: 2.611
# L2 Loss for 3.6912: 0.44275716000000026

# %%
## Now, let's implement Mean Squared Error (MSE) Loss

total_L2_loss = 0

for i, income in enumerate(x[:10, 0]):
    y_pred = w * income + b
    loss = ((y_pred - y[i])**2)
    total_L2_loss += loss
    print(f"Predicted value for {income}: {y_pred} , and target value: {y[i]}")
    print(f"MSE Loss for {income}: {loss}")

# Divided by 10, becuase we are only calculating the loss for the first 10 samples
mse_loss = total_L2_loss / 10
print(f"Mean Squared Error Loss: {mse_loss}")
# Out:
# Predicted value for 8.3252: 4.2626 , and target value: 4.526
# MSE Loss for 8.3252: 0.06937955999999992
# Predicted value for 8.3014: 4.250699999999999 , and target value: 3.585
# MSE Loss for 8.3014: 0.44315648999999907
# Predicted value for 7.2574: 3.7287 , and target value: 3.521
# MSE Loss for 7.2574: 0.04313929
# Predicted value for 5.6431: 2.92155 , and target value: 3.413
# MSE Loss for 5.6431: 0.24152310249999995
# Predicted value for 3.8462: 2.0231 , and target value: 3.422
# MSE Loss for 3.8462: 1.9569212100000006
# Predicted value for 4.0368: 2.1184000000000003 , and target value: 2.697
# MSE Loss for 4.0368: 0.33477795999999976
# Predicted value for 3.6591: 1.92955 , and target value: 2.992
# MSE Loss for 3.6591: 1.1288000024999998
# Predicted value for 3.12: 1.6600000000000001 , and target value: 2.414
# MSE Loss for 3.12: 0.568516
# Predicted value for 2.0804: 1.1402 , and target value: 2.267
# MSE Loss for 2.0804: 1.2696782399999995
# Predicted value for 3.6912: 1.9456 , and target value: 2.611
# MSE Loss for 3.6912: 0.44275716000000026
# Mean Squared Error Loss: 0.6498649014999998
